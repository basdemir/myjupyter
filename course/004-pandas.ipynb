# %%
import pandas as pd

# %%
gdp_world_data = pd.read_csv('data/gdp_world_data.csv', 'r', delimiter=',', index_col=0) # indexi okurken verebilirsin veya aşağıdaki gibi sonradan da verebilirsin

# %%
gdp_world_data = gdp_world_data.set_index('Country (or dependent territory)')

# %%
gdp_world_data
# Out:
#                                      1990     1991     1992     1993     1994  \
# Country (or dependent territory)
# Afghanistan                           NaN      NaN      NaN      NaN      NaN
# Albania                            2221.0   1333.0    843.0   1461.0   2361.0
# Algeria                           61892.0  46670.0  49217.0  50963.0  42426.0
# Angola                            11236.0  10891.0   8398.0   6095.0   4438.0
# Antigua and Barbuda                 459.0    482.0    499.0    535.0    589.0
# ...                                   ...      ...      ...      ...      ...
# Venezuela                         48391.0  53382.0  60400.0  59865.0  58357.0
# Vietnam                            6472.0   7642.0   9867.0  13181.0  16312.0
# Yemen                             12644.0  14665.0  17959.0  21737.0  28019.0
# Zambia                             4085.0   3690.0   3614.0   3549.0   3657.0
# Zimbabwe                           8780.0   8180.0   6746.0   6552.0   6889.0
#
# ...

# %%
type(gdp_world_data.loc['Albania'])
# Out:
# pandas.core.series.Series

# %%
seri = gdp_world_data.loc['Albania']

# %%
seri.index
# Out:
# Index(['1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998',
#        '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018', '2019'],
#       dtype='object')

# %%
seri['2008']
# Out:
# 12901.0

# %%
gdp_world_data.loc['Angola':'Armenia',:'1993']
# Out:
#                                       1990      1991      1992      1993
# Country (or dependent territory)
# Angola                             11236.0   10891.0    8398.0    6095.0
# Antigua and Barbuda                  459.0     482.0     499.0     535.0
# Argentina                         153205.0  205515.0  247987.0  256365.0
# Armenia                                NaN       NaN     108.0     835.0

# %%
gdp_world_data.loc['Angola':'Armenia',:'1993'].count()
# Out:
# 1990    3
# 1991    3
# 1992    4
# 1993    4
# dtype: int64

# %%
gdp_world_data.loc['Angola':'Armenia',:'1993'].sum()
# Out:
# 1990    164900.0
# 1991    216888.0
# 1992    256992.0
# 1993    263830.0
# dtype: float64

# %%
gdp_world_data.loc['Angola'].count()
# Out:
# 30
