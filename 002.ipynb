# %%
from dask.distributed import Client

client = Client("tcp://127.0.0.1:46399")
# client = Client(n_workers=4)
client
# Out:
# <Client: 'tcp://127.0.0.1:46399' processes=8 threads=32, memory=134.85 GB>

# %%
import numpy as np
import dask.array as da

# %%
np_tmp=np.random.randint(20, size=30)
np_tmp
# Out:
# array([ 3,  8,  0, 17, 17, 11, 10, 10, 17,  1, 19,  3,  7, 19, 12,  0,  9,
#         5, 14,  3,  1, 14,  0, 19, 19, 16, 18, 18, 19, 18])

# %%
np_arr = [11,  4,  9, 10, 12,  5, 18,  5, 15, 11, 16, 10, 10, 10,  2,  5, 18,
        6,  9,  0,  3,  0, 11, 10,  3, 14,  0,  0,  2,  5]

# %%
dask_arr=da.random.randint(20, size=30, chunks=3)
dask_arr
# Out:
# dask.array<randint, shape=(30,), dtype=int64, chunksize=(3,), chunktype=numpy.ndarray>

# %%
dask_arr.compute()
# Out:
# array([ 4,  1,  0, 15,  2,  5, 14,  6, 11, 16,  9, 11, 18,  2,  9, 16, 16,
#        11, 19, 14, 10,  4,  8,  1, 17,  7,  5,  0, 13, 15])

# %%
dask_arr.chunks
# Out:
# ((3, 3, 3, 3, 3, 3, 3, 3, 3, 3),)

# %%
dask_arr_from_np = da.from_array([ 3,  8,  0, 17, 17, 11, 10, 10, 17,  1, 19,  3,  7, 19, 12,  0,  9,
        5, 14,  3,  1, 14,  0, 19, 19, 16, 18, 18, 19, 18], chunks=5)

# %%
dask_arr_from_np
# Out:
# dask.array<array, shape=(30,), dtype=int64, chunksize=(5,), chunktype=numpy.ndarray>

# %%
dask_arr_from_np.chunks
# Out:
# ((5, 5, 5, 5, 5, 5),)

# %%
dask_arr_from_np.compute_chunk_sizes()
# Out:
# dask.array<array, shape=(30,), dtype=int64, chunksize=(5,), chunktype=numpy.ndarray>

# %%
dask_arr_from_np.compute()
# Out:
# array([ 3,  8,  0, 17, 17, 11, 10, 10, 17,  1, 19,  3,  7, 19, 12,  0,  9,
#         5, 14,  3,  1, 14,  0, 19, 19, 16, 18, 18, 19, 18])

# %%
dask_arr_from_np.sum().visualize()

# %%
dask_arr_from_np.max().visualize(rankdir="LR")

# %%
dask_arr_from_np.max()
# Out:
# dask.array<amax-aggregate, shape=(), dtype=int64, chunksize=(), chunktype=numpy.ndarray>
